# %% [markdown]
# ## Pull eo4wildfire codes to Drive

# %%
# !git clone https://github.com/puzhao89/EO4Wildfire.git

# %% [markdown]
# ## Load Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project" # Path to Project
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %%
# !pwd
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %% [markdown]
# ## Run Experiments

# %%
# https://github.com/qubvel/segmentation_models.pytorch#input-channels
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# !pip install imagecodecs
# !pip install prettyprinter
# !pip install kornia

# %%
# !python run_nrt_monitoring.py

# %% [markdown]
# ## Push to Github

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/puzhao89/EO4Wildfire.git
# !git push -u origin main

# %%
# !git config --global user.email "omegazhangpzh@gmail.com"
# !git config --global user.name "Puzhao"

# !git add .
# !git commit -m "eo4wildfire"
# !git push -u origin main

# %% [markdown]
# ## Pull eo4wildfire codes to Drive

# %%
# !git clone https://github.com/puzhao89/EO4Wildfire.git

# %% [markdown]
# ## Load Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# go to the path where this project locates.
project_dir = "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project"
# %cd $project_dir
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %%
# !pwd
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %% [markdown]
# ## Run Experiments

# %%
# https://github.com/qubvel/segmentation_models.pytorch#input-channels
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# !pip install imagecodecs
# !pip install prettyprinter
# !pip install kornia

# %%
# !python run_seg_model_BC_Wildfire.py

# %%
# !python run_evaluation.py

# %%
# !python run_nrt_monitoring.py
# Out:
# data_sampler
#
#  ==> Sampling over 20201019T19_DSC147.png
#
#  ==> Sampling over 20201031T19_DSC147.png
#
#  ==> Sampling over 20201112T19_DSC147.png
#
#  ==> Sampling over 20201124T19_DSC147.png
#
#  ==> Sampling over 20201206T19_DSC147.png
#
#  ==> Sampling over 20201212T19_DSC147.png
#
#  ==> Sampling over 20201218T19_DSC147.png
#
#  ==> Sampling over 20201224T19_DSC147.png
# easydict.EasyDict({
#     'project_dir': '/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project',
#     'nrt_data_folder':
#         '/content/drive/My '
#         'Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Temporal_Progressi'
#         'ons_Data/FraserIsland_Progression_Data_20m',
#     'input_folder': 'A0_Progression_PNG',
#     'transfer_folder': 'A0_Progression_PNG',
#     'patchsize': 256,
#     'num_patch_per_image': 500,
#     'train_val_split_rate': 0.7,
#     'random_state': 42,
#     'ARCH': 'UNet',
#     'ENCODER': 'resnet50',
#     'learning_rate': 1e-05,
#     'weight_decay': 0.0001,
#     'BATCH_SIZE': 32,
#     'max_score': 0,
#     'max_epoch': 10,
#     'size_of_train': 3072,
#     'gamma': 1,
#     'alpha': 0.5,
#     'beta': 2e-05,
#     'ref_mode': 'SAR',
#     'ENCODER_WEIGHTS': 'imagenet',
#     'ACTIVATION': 'sigmoid',
#     'CLASSES': ['fire'],
#     'DEVICE': 'cuda',
#     'verbose': True,
#     'data_sampler': <datasets.data_samping.NRT_DataSampler object at 0x7f0ee88290b8>
# })
# train expmPath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments
# train savePath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments/FraserIsland_20210201T201537_SAR_UNet_resnet50_a_0.5_b_2e-05_trainSize_3072
# ===> Network Architecture: UNet
#
# ==> 20201019T19_DSC147.png
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:319: UserWarning: This augmentation is deprecated. Please use Perspective instead
#   warnings.warn("This augmentation is deprecated. Please use Perspective instead")
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:185: UserWarning: This augmentation is deprecated. Please use Sharpen instead
#   warnings.warn("This augmentation is deprecated. Please use Sharpen instead")
# size of trainSet: 350
# size of trainSet: 150
# Size of Train/Val: 3072
#
# ==> train epoch: 0/10
# Train: 100% 96/96 [00:39<00:00,  2.41it/s, total_loss - 1.129, dice_loss - 0.9345, focal_loss - 0.1094, tv_loss - 0.08501, iou_score - 0.05762, fscore - 0.1072]
# Val: 100% 5/5 [00:01<00:00,  4.05it/s, total_loss - 1.082, dice_loss - 0.9588, focal_loss - 0.06942, tv_loss - 0.05349, iou_score - 0.04161, fscore - 0.07989]
# Model saved!
#
# ==> train epoch: 1/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 1.007, dice_loss - 0.9169, focal_loss - 0.06128, tv_loss - 0.02831, iou_score - 0.1449, fscore - 0.2457]
# Val: 100% 5/5 [00:01<00:00,  3.98it/s, total_loss - 1.022, dice_loss - 0.9569, focal_loss - 0.03898, tv_loss - 0.0262, iou_score - 0.05522, fscore - 0.1046]
# Model saved!
#
# ==> train epoch: 2/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.968, dice_loss - 0.904, focal_loss - 0.04565, tv_loss - 0.01841, iou_score - 0.2176, fscore - 0.3485]
# Val: 100% 5/5 [00:01<00:00,  3.93it/s, total_loss - 0.9978, dice_loss - 0.9565, focal_loss - 0.02421, tv_loss - 0.01705, iou_score - 0.05373, fscore - 0.1017]
# Model saved!
#
# ==> train epoch: 3/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.9498, dice_loss - 0.8954, focal_loss - 0.03849, tv_loss - 0.01588, iou_score - 0.2278, fscore - 0.3628]
# Val: 100% 5/5 [00:01<00:00,  3.94it/s, total_loss - 0.9882, dice_loss - 0.9536, focal_loss - 0.02026, tv_loss - 0.01442, iou_score - 0.06995, fscore - 0.1307]
# Model saved!
#
# ==> train epoch: 4/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.9342, dice_loss - 0.8882, focal_loss - 0.0318, tv_loss - 0.01419, iou_score - 0.2461, fscore - 0.3854]
# Val: 100% 5/5 [00:01<00:00,  4.00it/s, total_loss - 0.9819, dice_loss - 0.9517, focal_loss - 0.01743, tv_loss - 0.0127, iou_score - 0.07231, fscore - 0.1348]
# Model saved!
#
# ==> train epoch: 5/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.9261, dice_loss - 0.8853, focal_loss - 0.02742, tv_loss - 0.01338, iou_score - 0.246, fscore - 0.3846]
# Val: 100% 5/5 [00:01<00:00,  4.05it/s, total_loss - 0.9782, dice_loss - 0.95, focal_loss - 0.01633, tv_loss - 0.01191, iou_score - 0.07391, fscore - 0.1376]
# Model saved!
#
# ==> train epoch: 6/10
# Train: 100% 96/96 [00:40<00:00,  2.38it/s, total_loss - 0.9135, dice_loss - 0.8766, focal_loss - 0.02435, tv_loss - 0.01252, iou_score - 0.2569, fscore - 0.398]
# Val: 100% 5/5 [00:01<00:00,  4.03it/s, total_loss - 0.9747, dice_loss - 0.9507, focal_loss - 0.01375, tv_loss - 0.01025, iou_score - 0.07533, fscore - 0.14]
# Model saved!
#
# ==> train epoch: 7/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.9085, dice_loss - 0.8748, focal_loss - 0.02158, tv_loss - 0.01211, iou_score - 0.2591, fscore - 0.4017]
# Val: 100% 5/5 [00:01<00:00,  3.97it/s, total_loss - 0.9725, dice_loss - 0.9502, focal_loss - 0.01262, tv_loss - 0.009659, iou_score - 0.0761, fscore - 0.1414]
# Model saved!
#
# ==> train epoch: 8/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.899, dice_loss - 0.8679, focal_loss - 0.01931, tv_loss - 0.01174, iou_score - 0.268, fscore - 0.4138]
# Val: 100% 5/5 [00:01<00:00,  4.01it/s, total_loss - 0.9699, dice_loss - 0.9475, focal_loss - 0.01207, tv_loss - 0.01037, iou_score - 0.08092, fscore - 0.1497]
# Model saved!
#
# ==> train epoch: 9/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.8944, dice_loss - 0.865, focal_loss - 0.01785, tv_loss - 0.01161, iou_score - 0.2649, fscore - 0.4092]
# Val: 100% 5/5 [00:01<00:00,  4.00it/s, total_loss - 0.9668, dice_loss - 0.9458, focal_loss - 0.01102, tv_loss - 0.009927, iou_score - 0.08335, fscore - 0.1538]
# Model saved!
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Temporal_Progressions_Data/FraserIsland_Progression_Data_20m/A0_Progression_PNG/20201019T19_DSC147.png
# 100% 9/9 [00:03<00:00,  2.91it/s]
#
# ==> 20201031T19_DSC147.png
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:319: UserWarning: This augmentation is deprecated. Please use Perspective instead
#   warnings.warn("This augmentation is deprecated. Please use Perspective instead")
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:185: UserWarning: This augmentation is deprecated. Please use Sharpen instead
#   warnings.warn("This augmentation is deprecated. Please use Sharpen instead")
# size of trainSet: 700
# size of trainSet: 300
# Size of Train/Val: 3072
#
# ==> train epoch: 0/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.8649, dice_loss - 0.8378, focal_loss - 0.01568, tv_loss - 0.01138, iou_score - 0.304, fscore - 0.456]
# Val: 100% 10/10 [00:02<00:00,  4.48it/s, total_loss - 0.9686, dice_loss - 0.9499, focal_loss - 0.009074, tv_loss - 0.009592, iou_score - 0.08141, fscore - 0.1505]
# Model saved!
#
# ==> train epoch: 1/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.8586, dice_loss - 0.8331, focal_loss - 0.01443, tv_loss - 0.01111, iou_score - 0.3064, fscore - 0.4612]
# Val: 100% 10/10 [00:02<00:00,  4.53it/s, total_loss - 0.9676, dice_loss - 0.9495, focal_loss - 0.008542, tv_loss - 0.009483, iou_score - 0.08342, fscore - 0.1539]
# Model saved!
#
# ==> train epoch: 2/10
# Train: 100% 96/96 [00:40<00:00,  2.38it/s, total_loss - 0.8558, dice_loss - 0.8315, focal_loss - 0.01324, tv_loss - 0.01107, iou_score - 0.3047, fscore - 0.4594]
# Val: 100% 10/10 [00:02<00:00,  4.44it/s, total_loss - 0.9649, dice_loss - 0.9476, focal_loss - 0.00758, tv_loss - 0.009766, iou_score - 0.0893, fscore - 0.1638]
# Model saved!
#
# ==> train epoch: 3/10
# Train:  54% 52/96 [00:23<00:17,  2.51it/s, total_loss - 0.8567, dice_loss - 0.8337, focal_loss - 0.0121, tv_loss - 0.01095, iou_score - 0.3043, fscore - 0.4584]

# %%
you will stop here
# Out:
#   File "<ipython-input-33-59b7c2cd9d12>", line 1
#     you will stop here
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Push to Github

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# # !git push -u origin main

# %%
# !git config --global user.email "omegazhangpzh@gmail.com"
# !git config --global user.name "puzhao89"

# !git remote set-url origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# !git add .
# !git commit -m "eo4wildfire"
# !git push -u origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@a295ca927859.(none)')
# To https://github.com/puzhao89/eo4wildfire.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

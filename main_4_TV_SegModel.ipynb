# %% [markdown]
# ## Pull eo4wildfire codes to Drive

# %%
# !git clone https://github.com/puzhao89/EO4Wildfire.git

# %% [markdown]
# ## Load Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# go to the path where this project locates.
project_dir = "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project"
# %cd $project_dir
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %%
# !pwd
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %% [markdown]
# ## Run Experiments

# %%
# https://github.com/qubvel/segmentation_models.pytorch#input-channels
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# !pip install imagecodecs
# !pip install prettyprinter
# !pip install kornia

# %%
# !python run_seg_model_BC_Wildfire.py

# %%
# !python run_evaluation.py

# %%
# !python run_nrt_monitoring.py
# Out:
# data_sampler
#
#  ==> Sampling over 20201019T19_DSC147.png
#
#  ==> Sampling over 20201031T19_DSC147.png
#
#  ==> Sampling over 20201112T19_DSC147.png
#
#  ==> Sampling over 20201124T19_DSC147.png
#
#  ==> Sampling over 20201206T19_DSC147.png
#
#  ==> Sampling over 20201212T19_DSC147.png
#
#  ==> Sampling over 20201218T19_DSC147.png
#
#  ==> Sampling over 20201224T19_DSC147.png
# easydict.EasyDict({
#     'project_dir': '/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project',
#     'nrt_data_folder':
#         '/content/drive/My '
#         'Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Temporal_Progressi'
#         'ons_Data/FraserIsland_Progression_Data_20m',
#     'input_folder': 'A0_Progression_PNG',
#     'transfer_folder': 'A0_Progression_PNG',
#     'patchsize': 256,
#     'num_patch_per_image': 500,
#     'train_val_split_rate': 0.7,
#     'random_state': 42,
#     'ARCH': 'UNet',
#     'ENCODER': 'resnet50',
#     'learning_rate': 1e-05,
#     'weight_decay': 0.0001,
#     'BATCH_SIZE': 32,
#     'max_score': 0,
#     'max_epoch': 10,
#     'size_of_train': 3072,
#     'gamma': 1,
#     'alpha': 0.5,
#     'beta': 0,
#     'ref_mode': 'SAR',
#     'ENCODER_WEIGHTS': 'imagenet',
#     'ACTIVATION': 'sigmoid',
#     'CLASSES': ['fire'],
#     'DEVICE': 'cuda',
#     'verbose': True,
#     'data_sampler': <datasets.data_samping.NRT_DataSampler object at 0x7f4fe960b400>
# })
# train expmPath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments
# train savePath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments/FraserIsland_20210201T200246_SAR_UNet_resnet50_a_0.5_b_0_trainSize_3072
# ===> Network Architecture: UNet
#
# ==> 20201019T19_DSC147.png
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:319: UserWarning: This augmentation is deprecated. Please use Perspective instead
#   warnings.warn("This augmentation is deprecated. Please use Perspective instead")
# /usr/local/lib/python3.6/dist-packages/albumentations/imgaug/transforms.py:185: UserWarning: This augmentation is deprecated. Please use Sharpen instead
#   warnings.warn("This augmentation is deprecated. Please use Sharpen instead")
# size of trainSet: 350
# size of trainSet: 150
# Size of Train/Val: 3072
#
# ==> train epoch: 0/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 1.023, dice_loss - 0.9184, focal_loss - 0.105, tv_loss - 0.0, iou_score - 0.05198, fscore - 0.09756]
# Val: 100% 5/5 [00:01<00:00,  3.98it/s, total_loss - 1.022, dice_loss - 0.9543, focal_loss - 0.06802, tv_loss - 0.0, iou_score - 0.03459, fscore - 0.06686]
# Model saved!
#
# ==> train epoch: 1/10
# Train: 100% 96/96 [00:40<00:00,  2.40it/s, total_loss - 0.9496, dice_loss - 0.895, focal_loss - 0.05459, tv_loss - 0.0, iou_score - 0.08837, fscore - 0.1609]
# Val: 100% 5/5 [00:01<00:00,  4.01it/s, total_loss - 1.02, dice_loss - 0.9497, focal_loss - 0.07023, tv_loss - 0.0, iou_score - 0.04213, fscore - 0.08086]
# Model saved!
#
# ==> train epoch: 2/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.9209, dice_loss - 0.8783, focal_loss - 0.04262, tv_loss - 0.0, iou_score - 0.1065, fscore - 0.1907]
# Val: 100% 5/5 [00:01<00:00,  3.98it/s, total_loss - 1.046, dice_loss - 0.9471, focal_loss - 0.0985, tv_loss - 0.0, iou_score - 0.04574, fscore - 0.08748]
# Model saved!
#
# ==> train epoch: 3/10
# Train: 100% 96/96 [00:40<00:00,  2.39it/s, total_loss - 0.9093, dice_loss - 0.8708, focal_loss - 0.03848, tv_loss - 0.0, iou_score - 0.1206, fscore - 0.2129]
# Val: 100% 5/5 [00:01<00:00,  4.04it/s, total_loss - 0.9941, dice_loss - 0.9437, focal_loss - 0.05037, tv_loss - 0.0, iou_score - 0.05192, fscore - 0.09871]
# Model saved!
#
# ==> train epoch: 4/10
# Train: 100% 96/96 [00:40<00:00,  2.38it/s, total_loss - 0.8975, dice_loss - 0.8636, focal_loss - 0.03392, tv_loss - 0.0, iou_score - 0.1431, fscore - 0.2459]
# Val: 100% 5/5 [00:01<00:00,  4.02it/s, total_loss - 1.003, dice_loss - 0.9424, focal_loss - 0.06036, tv_loss - 0.0, iou_score - 0.0592, fscore - 0.1118]
# Model saved!
#
# ==> train epoch: 5/10
# Train:   6% 6/96 [00:04<01:06,  1.35it/s, total_loss - 0.856, dice_loss - 0.8245, focal_loss - 0.03158, tv_loss - 0.0, iou_score - 0.1829, fscore - 0.3028]

# %%
you will stop here
# Out:
#   File "<ipython-input-33-59b7c2cd9d12>", line 1
#     you will stop here
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Push to Github

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# # !git push -u origin main

# %%
# !git config --global user.email "omegazhangpzh@gmail.com"
# !git config --global user.name "puzhao89"

# !git remote set-url origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# !git add .
# !git commit -m "eo4wildfire"
# !git push -u origin main
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@a295ca927859.(none)')
# To https://github.com/puzhao89/eo4wildfire.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

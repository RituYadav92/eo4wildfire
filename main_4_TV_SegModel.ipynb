# %% [markdown]
# ## Pull eo4wildfire codes to Drive

# %%
# !git clone https://github.com/puzhao89/EO4Wildfire.git

# %% [markdown]
# ## Load Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# go to the path where this project locates.
project_dir = "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project"
# %cd $project_dir
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %%
# !pwd
# Out:
# /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project

# %% [markdown]
# ## Run Experiments

# %%
# https://github.com/qubvel/segmentation_models.pytorch#input-channels
# !pip install git+https://github.com/qubvel/segmentation_models.pytorch
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# !pip install imagecodecs
# !pip install prettyprinter
# !pip install kornia

# %%
# !python run_seg_model_BC_Wildfire.py
# Out:
# data_sampler
#
#  ==> Sampling over BC2017C20729_20170906T01_ASC64.png
# opt_ref_url /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Historical_Wildfire_Dataset/BC_SAR4Wildfire_Dataset/A3_Opt_Reference_Masks/BC2017C20729_20170907T14_DSC86_optRef.png
#  ref: [(0.0, 1.0)], ref shape: (1349, 838), input shape: (1349, 838, 3), optSAR shape: (1349, 838)
# 100% 70/70 [00:04<00:00, 16.70it/s]
# 100% 30/30 [00:01<00:00, 17.88it/s]
#
#  ==> Sampling over BC2017C20735_20170906T01_ASC64.png
# opt_ref_url /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Historical_Wildfire_Dataset/BC_SAR4Wildfire_Dataset/A3_Opt_Reference_Masks/BC2017C20735_20170826T14_DSC86_optRef.png
#  ref: [(0.0, 1.0)], ref shape: (903, 1125), input shape: (903, 1125, 3), optSAR shape: (903, 1125)
# 100% 70/70 [00:04<00:00, 14.40it/s]
# 100% 30/30 [00:01<00:00, 20.71it/s]
#
#  ==> Sampling over BC2017C20735_20170826T14_DSC86.png
# opt_ref_url /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Historical_Wildfire_Dataset/BC_SAR4Wildfire_Dataset/A3_Opt_Reference_Masks/BC2017C20735_20170826T14_DSC86_optRef.png
#  ref: [(0.0, 1.0)], ref shape: (903, 1125), input shape: (903, 1125, 3), optSAR shape: (903, 1125)
# 100% 70/70 [00:05<00:00, 13.38it/s]
# 100% 30/30 [00:01<00:00, 19.50it/s]
#
#  ==> Sampling over BC2017C20729_20170907T14_DSC86.png
# opt_ref_url /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Historical_Wildfire_Dataset/BC_SAR4Wildfire_Dataset/A3_Opt_Reference_Masks/BC2017C20729_20170907T14_DSC86_optRef.png
#  ref: [(0.0, 1.0)], ref shape: (1349, 838), input shape: (1349, 838, 3), optSAR shape: (1349, 838)
# 100% 70/70 [00:04<00:00, 15.97it/s]
# 100% 30/30 [00:01<00:00, 17.52it/s]
#
#  ==> Sampling over C10784_20171001T14_DSC86.png
# opt_ref_url /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Historical_Wildfire_Dataset/BC_SAR4Wildfire_Dataset/A3_Opt_Reference_Masks/C10784_20171029T19_S2_optRef.png
#  ref: [(0.0, 1.0)], ref shape: (5034, 6115), input shape: (5034, 6115, 3), optSAR shape: (5034, 6115)
# tcmalloc: large alloc 1477582848 bytes == 0x4bdf4000 @  0x7f81d67d61e7 0x7f8186e1d41e 0x7f8186e6dc2b 0x7f8186e6dcc8 0x7f8186f14fb0 0x7f8186f156dc 0x7f8186f157fd 0x566f73 0x59fd0e 0x7f8186e5aea7 0x50a12f 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x508cd5 0x594a01 0x54a971 0x5a9dac 0x50a433 0x50beb4 0x507be4 0x50ad03 0x634e72
#  30% 21/70 [00:01<00:02, 16.52it/s]

# %%
# !python run_evaluation.py

# %%
# !python run_nrt_monitoring.py
# Out:
# data_sampler
#
#  ==> Sampling over 20201019T19_DSC147.png
#
#  ==> Sampling over 20201031T19_DSC147.png
# 100% 350/350 [00:08<00:00, 39.63it/s]
# 100% 150/150 [00:03<00:00, 42.24it/s]
#
#  ==> Sampling over 20201112T19_DSC147.png
# 100% 350/350 [00:09<00:00, 37.87it/s]
# 100% 150/150 [00:03<00:00, 40.06it/s]
#
#  ==> Sampling over 20201124T19_DSC147.png
# 100% 350/350 [00:09<00:00, 36.88it/s]
# 100% 150/150 [00:03<00:00, 39.54it/s]
#
#  ==> Sampling over 20201206T19_DSC147.png
# 100% 350/350 [00:09<00:00, 36.76it/s]
# 100% 150/150 [00:03<00:00, 39.12it/s]
#
#  ==> Sampling over 20201212T19_DSC147.png
# 100% 350/350 [00:09<00:00, 35.47it/s]
# 100% 150/150 [00:03<00:00, 37.78it/s]
#
#  ==> Sampling over 20201218T19_DSC147.png
# 100% 350/350 [00:09<00:00, 36.28it/s]
# 100% 150/150 [00:03<00:00, 38.78it/s]
#
#  ==> Sampling over 20201224T19_DSC147.png
# 100% 350/350 [00:09<00:00, 37.25it/s]
# 100% 150/150 [00:03<00:00, 38.97it/s]
# easydict.EasyDict({
#     'project_dir': '/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project',
#     'nrt_data_folder':
#         '/content/drive/My '
#         'Drive/A_Wildfire_Projects/EO4Wildfire_Project/Data/Temporal_Progressi'
#         'ons_Data/FraserIsland_Progression_Data_20m',
#     'input_folder': 'A0_Progression_PNG',
#     'transfer_folder': 'A0_Progression_PNG',
#     'patchsize': 256,
#     'num_patch_per_image': 500,
#     'train_val_split_rate': 0.7,
#     'random_state': 42,
#     'ARCH': 'UNet',
#     'ENCODER': 'resnet50',
#     'learning_rate': 1e-05,
#     'weight_decay': 0.0001,
#     'BATCH_SIZE': 32,
#     'max_score': 0,
#     'max_epoch': 10,
#     'size_of_train': 3072,
#     'gamma': 1,
#     'alpha': 0.5,
#     'beta': 2e-05,
#     'ref_mode': 'SARREF',
#     'ENCODER_WEIGHTS': 'imagenet',
#     'ACTIVATION': 'sigmoid',
#     'CLASSES': ['fire'],
#     'DEVICE': 'cuda',
#     'verbose': True,
#     'data_sampler': <datasets.data_samping.NRT_DataSampler object at 0x7f9a0c749400>
# })
# train expmPath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments
# train savePath: /content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/Experiments/FraserIsland_20210201T204638_SARREF_UNet_resnet50_a_0.5_b_2e-05_trainSize_3072
# ===> Network Architecture: UNet
# Traceback (most recent call last):
#   File "run_nrt_monitoring.py", line 68, in <module>
#     seg_model = SegModel(cfg)
#   File "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/models/seg_model_nrt.py", line 169, in __init__
#     self.set_train_val_dir()
#   File "/content/drive/My Drive/A_Wildfire_Projects/EO4Wildfire_Project/models/seg_model_nrt.py", line 189, in set_train_val_dir
#     self.y_test_dir = self.y_valid_dir
# AttributeError: 'SegModel' object has no attribute 'y_valid_dir'

# %%
you will stop here
# Out:
#   File "<ipython-input-33-59b7c2cd9d12>", line 1
#     you will stop here
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Push to Github

# %%
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# # !git push -u origin main

# %%
# !git config --global user.email "omegazhangpzh@gmail.com"
# !git config --global user.name "puzhao89"

# !git remote set-url origin https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git
# !git add .
# !git commit -m "eo4wildfire"
# !git push -u origin main
# Out:
# [main 3b05158] eo4wildfire
#  2 files changed, 2 insertions(+), 2 deletions(-)
# To https://github.com/puzhao89/eo4wildfire.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://puzhao89:kth10044!@github.com/puzhao89/eo4wildfire.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
